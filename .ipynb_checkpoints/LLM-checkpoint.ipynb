# %%
import random
import pandas as pd

cat_sentences = [
    "Cats are often valued by humans for companionship.",
    "A cat can either be a house cat, a farm cat, or a feral cat.",
    "Cats are skilled predators and can hunt over 1,000 species for food.",
    "Cats communicate by meowing, purring, trilling, hissing, growling, and grunting.",
    "A group of cats is referred to as a clowder or a glaring.",
    "Domestic cats are a major source of allergens.",
    "Cats have been domesticated for nearly 10,000 years.",
    "A cat's whiskers are used to measure gaps and distances.",
    "The oldest recorded pet cat lived 38 years.",
    "Cats conserve energy by sleeping more than most animals.",
    "Most breeds of cats have a genetic mutation that prevents them from tasting sweetness.",
    "Cats have a high breeding rate.",
    "The first cat in space was a French cat named Félicette in 1963.",
    "Cats have a strong territorial instinct.",
    "Cats' hearing is much more sensitive than humans and dogs.",
    "Cats can rotate their ears 180 degrees.",
    "The cat's tongue has sharp spines, or papillae, useful for grooming and tearing food.",
    "Cats can make about 100 different sounds.",
    "In ancient Egypt, cats were sacred animals.",
    "Each cat's nose print is unique, much like human fingerprints.",
    "These felines often enjoy lounging in sunny spots.",
    "Known for their playful attitude, they chase laser pointers and strings.",
    "These creatures purr when content and knead with their paws.",
    "Predatory by nature, they are adept at stalking and pouncing.",
    "These animals are often seen grooming themselves meticulously.",
    "Their eyes are highly adapted to low-light conditions.",
    "They are known for landing on their feet due to their flexible spine.",
    "Some breeds have distinctive fur patterns and colors.",
    "Their nocturnal habits make them more active at night.",
    "Renowned for their curiosity, they often explore new environments.",
    "These whiskered hunters display remarkable dexterity.",
    "Often basking in the sun, they seem to revel in its warmth.",
    "These silent stalkers can spend hours watching over their territory.",
    "Their nocturnal yowls can sometimes disturb the quiet of the night.",
    "These animals have a fondness for high vantage points.",
    "Elegantly padding on silent paws, they can approach unnoticed.",
    "Their grooming rituals are both a hygiene practice and a way to relax.",
    "They often use subtle body language to communicate with each other.",
    "A naturally occurring curiosity can sometimes lead them into mischief.",
    "Their predatory instincts are often observed during playful behavior.",
    "Cats are known for their independent nature and their ability to take care of themselves.",
    "One of the most common questions that cat owners have is whether or not they can use a pet hair remover on their cat.",
    "First you should make sure that the pet hair remover that you are using is safe for cats",
    "Tigers are the largest of the big cats and are the most powerful of all the big cats.",
    "They are also the only cats that can jump higher than they can run.",
    "FIV is a retrovirus that infects the T-cell lymphocytes of the cat.", 
    "The most popular pets in the world are dogs and cats.",
    "Cat food is a very important part of your cat’s diet.",
    "It is important to choose the right food for your cat because it can affect their health and well-being."
]

cat_dataset = pd.DataFrame({
    'Text': cat_sentences,
    'Label': ['Cat'] * len(cat_sentences)
})

cat_dataset.head(15)
# Out:
#                                                  Text Label
# 0   Cats are often valued by humans for companions...   Cat
# 1   A cat can either be a house cat, a farm cat, o...   Cat
# 2   Cats are skilled predators and can hunt over 1...   Cat
# 3   Cats communicate by meowing, purring, trilling...   Cat
# 4   A group of cats is referred to as a clowder or...   Cat
# 5      Domestic cats are a major source of allergens.   Cat
# 6   Cats have been domesticated for nearly 10,000 ...   Cat
# 7   A cat's whiskers are used to measure gaps and ...   Cat
# 8         The oldest recorded pet cat lived 38 years.   Cat
# 9   Cats conserve energy by sleeping more than mos...   Cat
# 10  Most breeds of cats have a genetic mutation th...   Cat
# 11                    Cats have a high breeding rate.   Cat
# 12  The first cat in space was a French cat named ...   Cat
# 13           Cats have a strong territorial instinct.   Cat
# 14  Cats' hearing is much more sensitive than huma...   Cat

# %%
non_cat_sentences = [
    "Dogs are known for their loyalty and friendliness.",
    "The sun is a star at the center of the Solar System.",
    "Apples are a popular fruit and contain essential nutrients.",
    "Cars have revolutionized transportation in the modern era.",
    "Mount Everest is the Earth's highest mountain above sea level.",
    "Shakespeare was a famous English playwright and poet.",
    "Computers are electronic devices that process data.",
    "Basketball is a popular sport involving two teams of five players.",
    "The ocean covers over seventy percent of the Earth's surface.",
    "Photosynthesis is the process by which green plants create energy.",
    "Beethoven was a renowned composer and pianist.",
    "The Amazon rainforest is the largest tropical rainforest in the world.",
    "Pandas are known for their distinctive black and white coloring.",
    "The Moon orbits the Earth and is its only permanent natural satellite.",
    "The Great Wall of China is thousands of miles long.",
    "Coffee is a brewed drink prepared from roasted coffee beans.",
    "Penguins are flightless birds that live primarily in the Southern Hemisphere.",
    "The Sahara is the largest hot desert in the world.",
    "Roses are commonly known for their fragrance and are used in perfumery.",
    "Honey is a sweet substance made by bees using nectar from flowers.",
    "These canines are often kept as loyal and protective companions.",
    "Flowering plants add beauty and fragrance to gardens.",
    "Smartphones have become an essential part of modern communication.",
    "Birds are admired for their ability to fly and melodious songs.",
    "Aquatic creatures in oceans and rivers exhibit a fascinating diversity.",
    "Mountains are known for their majestic heights and scenic beauty.",
    "Artificial intelligence is shaping the future of technology.",
    "Photography captures moments and preserves memories.",
    "The culinary art involves creativity in cooking and presentation.",
    "Astronomy explores the mysteries of stars and galaxies.",
    "These canines are often seen as symbols of fidelity and bravery.",
    "Lush green forests are the lungs of our planet, absorbing carbon dioxide.",
    "Portable devices have become ubiquitous in everyday life.",
    "The agile flyers weave through the trees, chirping melodically.",
    "The depths of the sea hold untold secrets, teeming with life.",
    "The peaks offer breathtaking vistas, often capped with snow.",
    "Machines learning from data can seem like science fiction come to life.",
    "Capturing light and shadows, photographers tell stories without words.",
    "Gourmet chefs turn simple ingredients into visual and flavorful feasts.",
    "Stargazers seek the patterns woven across the celestial dome.",
    "Dogs are not only man’s best friend, but they are also a great source of entertainment.",
    "Books are a great way to learn about the world and the people who live in it. They can also be a great way to learn about yourself.",
    "The Enneagram is a system of nine personality types that are based on the idea that each person has a unique set of strengths and weaknesses.",
    "Pandas are also one of the most popular animals in the world.",
    "There is no one definitive answer to this question.",
    "Magic The Gathering is a game that has been around for a long time and has a lot of different cards.",
    "Ostrich is a large flightless bird that is native to Africa.",
    "It is the largest living species of bird, and is known for its long neck and legs.",
    "Non-nutritional allergy is a common problem in children.",
    "Eyebags are a common problem for many people.",
    "Penguins are a group of flightless birds that live in the Southern hemisphere.",
    "Wheels are the most important part of a car."
]
non_cat_dataset = pd.DataFrame({
    'Text': non_cat_sentences,
    'Label': ['Non-Cat'] * len(non_cat_sentences)
})
non_cat_dataset.head(15)
# Out:
#                                                  Text    Label
# 0   Dogs are known for their loyalty and friendlin...  Non-Cat
# 1   The sun is a star at the center of the Solar S...  Non-Cat
# 2   Apples are a popular fruit and contain essenti...  Non-Cat
# 3   Cars have revolutionized transportation in the...  Non-Cat
# 4   Mount Everest is the Earth's highest mountain ...  Non-Cat
# 5   Shakespeare was a famous English playwright an...  Non-Cat
# 6   Computers are electronic devices that process ...  Non-Cat
# 7   Basketball is a popular sport involving two te...  Non-Cat
# 8   The ocean covers over seventy percent of the E...  Non-Cat
# 9   Photosynthesis is the process by which green p...  Non-Cat
# 10     Beethoven was a renowned composer and pianist.  Non-Cat
# 11  The Amazon rainforest is the largest tropical ...  Non-Cat
# 12  Pandas are known for their distinctive black a...  Non-Cat
# 13  The Moon orbits the Earth and is its only perm...  Non-Cat
# ...

# %%
combined_dataset = pd.concat([cat_dataset, non_cat_dataset], ignore_index=True)

# %%
combined_dataset.describe()
# Out:
#                                                      Text    Label
# count                                                 101      101
# unique                                                101        2
# top     Cats are often valued by humans for companions...  Non-Cat
# freq                                                    1       52

# %%
combined_dataset = combined_dataset.drop_duplicates(subset=['Text'])
combined_dataset.describe()
# Out:
#                                                      Text    Label
# count                                                 101      101
# unique                                                101        2
# top     Cats are often valued by humans for companions...  Non-Cat
# freq                                                    1       52

# %%
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
import nltk
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
import re

lemmatizer = WordNetLemmatizer()

def preprocess_text(text):
    text = text.lower()
    text = re.sub(r'[^\w\s]', '', text)
    text = re.sub(r'\d+', '', text)
    words = text.split()
    words = [word for word in words if word not in stopwords.words('english')]
    words = [lemmatizer.lemmatize(word) for word in words]
    text = ' '.join(words)
    return text

combined_dataset['Processed_Text'] = combined_dataset['Text'].apply(preprocess_text)

X_train, X_test, y_train, y_test = train_test_split(combined_dataset['Processed_Text'], 
                                                    combined_dataset['Label'], 
                                                    test_size=0.2,
                                                    random_state=42,
                                                    stratify=combined_dataset['Label'])

tfidf_vectorizer = TfidfVectorizer()

X_train_tfidf = tfidf_vectorizer.fit_transform(X_train)
X_test_tfidf = tfidf_vectorizer.transform(X_test)

X_train_tfidf.shape, X_test_tfidf.shape
# Out:
# ((80, 371), (21, 371))

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score

log_reg = LogisticRegression()

log_reg.fit(X_train_tfidf, y_train)

y_pred = log_reg.predict(X_test_tfidf)

accuracy = accuracy_score(y_test, y_pred)

class_report = classification_report(y_test, y_pred)

conf_matrix = confusion_matrix(y_test, y_pred)

accuracy
# Out:
# 0.9523809523809523

# %%
class_report
# Out:
# '              precision    recall  f1-score   support\n\n         Cat       1.00      0.90      0.95        10\n     Non-Cat       0.92      1.00      0.96        11\n\n    accuracy                           0.95        21\n   macro avg       0.96      0.95      0.95        21\nweighted avg       0.96      0.95      0.95        21\n'

# %%
conf_matrix
# Out:
# array([[ 9,  1],
#        [ 0, 11]], dtype=int64)

# %%
from transformers import BertTokenizer, BertForSequenceClassification
import torch
from torch.utils.data import DataLoader, SequentialSampler, TensorDataset
from torch.nn.functional import softmax

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')
model = BertForSequenceClassification.from_pretrained('bert-base-uncased', num_labels=2).to(device)

encoded_test = tokenizer(list(X_test), 
                         padding=True, 
                         truncation=True, 
                         max_length=512, 
                         return_tensors="pt")

test_dataset = TensorDataset(encoded_test['input_ids'], 
                             encoded_test['attention_mask'])

test_dataloader = DataLoader(test_dataset, 
                             sampler=SequentialSampler(test_dataset), 
                             batch_size=32)

model.eval()
predictions = []
for batch in test_dataloader:
    batch = tuple(t.to(device) for t in batch)
    inputs, masks = batch
    with torch.no_grad():
        outputs = model(inputs, attention_mask=masks)
    
    logits = outputs.logits.detach().cpu()
    probabilities = softmax(logits, dim=1)
    predictions.extend(probabilities.argmax(dim=1).tolist())

final_predictions = ['Cat' if pred == 1 else 'Non-Cat' for pred in predictions]

final_predictions
# Out:
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-uncased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# ['Cat',
#  'Cat',
#  'Non-Cat',
#  'Non-Cat',
#  'Non-Cat',
#  'Non-Cat',
#  'Non-Cat',
#  'Non-Cat',
#  'Cat',
#  'Cat',
#  'Non-Cat',
#  'Non-Cat',
#  'Non-Cat',
#  'Non-Cat',
#  'Non-Cat',
#  'Non-Cat',
#  'Non-Cat',
#  'Cat',
#  'Cat',
#  'Non-Cat',
#  'Cat']

# %%
from sklearn.metrics import accuracy_score, precision_recall_fscore_support

label_to_int = {'Cat': 1, 'Non-Cat': 0}

true_labels_encoded = [label_to_int[label] for label in y_test]

predictions_encoded = [label_to_int[label] for label in final_predictions]

accuracy = accuracy_score(true_labels_encoded, predictions_encoded)
precision, recall, f1, _ = precision_recall_fscore_support(true_labels_encoded, predictions_encoded, average='binary')

print(f"Accuracy: {accuracy:.4f}")
print(f"Precision: {precision:.4f}")
print(f"Recall: {recall:.4f}")
print(f"F1 Score: {f1:.4f}")
# Out:
# Accuracy: 0.5714
# Precision: 0.5714
# Recall: 0.4000
# F1 Score: 0.4706
